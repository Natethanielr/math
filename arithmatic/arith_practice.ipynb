# %%
import numpy as np
import random

# %%
print(random.randrange(1, 10, 1))
# Out:
# 3

# %%
x = random.randrange(1,10,1)
y = random.randrange(1,10,1)
solution = x*y
print(f'evaluate {x} * {y}')
answer = int(input())
if answer == solution:
    print('Yay')
else: 
    print('Wrong')
# Out:
# evaluate 5 * 2
#  10
# Yay

# %%
right = 0
wrong = 0
length = int(input('How many rounds')
for i in range(length):
    x = random.randrange(1,10,1)
    y = random.randrange(1,10,1)
    solution = x*y
    print(f'evaluate {x} * {y}')
    answer = int(input())
    if answer == solution:
        print('Yay')
        right += 1
    else: 
        print('Wrong')
        wrong += 1
print(f'you got {right}/{leng')
# Out:
# evaluate 8 * 3
#  21
# Wrong
# evaluate 1 * 2
#  2
# Yay
# evaluate 4 * 6
#  24
# Yay
# you got 2/3
